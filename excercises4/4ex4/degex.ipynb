# %% [markdown]
# Given: A simple graph with n≤103
#  vertices in the edge list format.
#
# Return: An array D[1..n]
#  where D[i]
#  is the degree of vertex  i

# %%
dcount = [0] * 1000 
with open("rosalind_deg.txt", "r") as f:
    nodes, edges = map(int, f.readline().strip().split(" "))
    for line in f:
        u, v = map(int, line.strip().split(" "))
        dcount[u - 1] += 1 
        dcount[v - 1] += 1  


outputd = " ".join(map(str, dcount[:nodes])) 
print(outputd)
# Out:
# 25 20 18 20 20 15 21 15 15 20 17 23 21 17 23 23 25 21 14 20 21 19 17 24 32 21 25 27 23 29 22 34 25 17 14 13 18 26 25 22 18 21 22 26 14 22 17 17 15 24 15 22 20 20 20 14 12 18 21 17 26 19 19 23 17 15 24 18 18 22 24 16 26 16 16 9 20 18 14 20 15 24 19 26 23 17 21 21 15 15 18 14 19 17 23 24 17 17 18 10 12 16 20 16 25 17 26 30 26 17 22 20 21 20 31 21 23 18 23 16 21 17 23 22 19 23 18 24 22 23 26 22 22 10 19 15 20 12 21 19 19 24 18 13 19 23 26 19 15 29 15 15 16 16 18 10 23 19 11 22 20 23 19 31 32 20 18 20 21 12 28 24 19 16 18 21 22 22 22 19 24 23 24 20 17 15 25 26 16 21 25 21 27 26 15 13 18 22 23 23 20 29 13 21 16 24 16 19 20 25 13 19 15 17 23 26 14 13 21 18 25 18 19 17 19 21 22 20 17 15 19 17 30 19 25 18 19 17 12 24 29 16 19 12 17 20 17 21 28 19 23 16 20 15 21 11 13 24 24 19 27 18 25 8 19 19 21 9 24 23 21 18 15 11 16 25 17 20 27 18 12 18 30 18 21 20 17 18 26 16 15 18 26 13 17 13 22 20 22 22 24 26 17 20 16 32 20 17 21 17 21 25 16 20 20 33 25 31 21 19 12 19 26 15 25 24 24 20 24 20 19 21 21 24
# ...
